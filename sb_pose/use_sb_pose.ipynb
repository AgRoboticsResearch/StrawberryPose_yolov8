# %% [markdown]
# Necessary imports for displaying points, boxes, and masks.

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import cv2
from ultralytics import YOLO

# %%
image = cv2.imread('/mnt/TempData/brl/pangolin/ruichen/Strawberry_yolov8/strawberry.png')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(image)
plt.axis('on')
plt.show()

# %% [markdown]
# use the model to predict on an example image

# %%
# Load a model
model = YOLO('/mnt/TempData/brl/pangolin/ruichen/Strawberry_yolov8/model/pose_ud.pt')  # load a custom model

# Predict with the model
results = model('/mnt/TempData/brl/pangolin/ruichen/Strawberry_yolov8/strawberry.png')  # predict on an image

print(results[0].keypoints)
res = results[0].plot()

plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))   #转换色调，BGR到RGB
# Out:
# image 1/1 /mnt/TempData/brl/pangolin/ruichen/Strawberry_yolov8/strawberry.png: 480x640 5 unripes, 4.5ms
# Speed: 1.3ms preprocess, 4.5ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
# ultralytics.engine.results.Keypoints object with attributes:
#
# conf: tensor([[0.9899, 0.9967, 0.9911, 0.9992, 0.9662],
#         [0.9981, 0.9993, 0.9969, 0.9990, 0.9979],
#         [0.9943, 0.9959, 0.9738, 0.9915, 0.9924],
#         [0.9923, 0.9961, 0.9846, 0.9909, 0.9926],
#         [0.9993, 0.9997, 0.9965, 0.9998, 0.9948]], device='cuda:0')
# data: tensor([[[504.6993, 232.9743,   0.9899],
#          [490.9736, 279.7089,   0.9967],
#          [458.6120, 399.1486,   0.9911],
#          [443.3494, 306.6835,   0.9992],
#          [513.1638, 329.7834,   0.9662]],
#
#         [[738.3478, 163.6394,   0.9981],
#          [746.7966, 218.9283,   0.9993],
#          [767.4279, 323.1101,   0.9969],
#          [715.5385, 262.4314,   0.9990],
#          [789.1559, 245.9961,   0.9979]],
#
# ...
